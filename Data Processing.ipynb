# %%
import pandas as pd

# %%
def data_join (transactionFile, identityFile):
    transactions = pd.read_csv(transactionFile)
    identity = pd.read_csv(identityFile)
    joined = transactions.merge(identity, how='left', on='TransactionID')
    return joined

# %%
trainTransactions = 'Data/train_transaction.csv'
trainIdentity = 'Data/train_identity.csv'
train_df = data_join(trainTransactions, trainIdentity)
train_df.head()
# Out:
#    TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  card1  \
# 0        2987000        0          86400            68.5         W  13926
# 1        2987001        0          86401            29.0         W   2755
# 2        2987002        0          86469            59.0         W   4663
# 3        2987003        0          86499            50.0         W  18132
# 4        2987004        0          86506            50.0         H   4497
#
#    card2  card3       card4  card5              ...                \
# 0    NaN  150.0    discover  142.0              ...
# 1  404.0  150.0  mastercard  102.0              ...
# 2  490.0  150.0        visa  166.0              ...
# 3  567.0  150.0  mastercard  117.0              ...
# 4  514.0  150.0  mastercard  102.0              ...
#
#                  id_31  id_32      id_33           id_34  id_35 id_36 id_37  \
# 0                  NaN    NaN        NaN             NaN    NaN   NaN   NaN
# ...

# %%
x_train = train_df.iloc[0:,3:]
x_train.head()
# Out:
#    TransactionAmt ProductCD  card1  card2  card3       card4  card5   card6  \
# 0            68.5         W  13926    NaN  150.0    discover  142.0  credit
# 1            29.0         W   2755  404.0  150.0  mastercard  102.0  credit
# 2            59.0         W   4663  490.0  150.0        visa  166.0   debit
# 3            50.0         W  18132  567.0  150.0  mastercard  117.0   debit
# 4            50.0         H   4497  514.0  150.0  mastercard  102.0  credit
#
#    addr1  addr2              ...                              id_31  id_32  \
# 0  315.0   87.0              ...                                NaN    NaN
# 1  325.0   87.0              ...                                NaN    NaN
# 2  330.0   87.0              ...                                NaN    NaN
# 3  476.0   87.0              ...                                NaN    NaN
# 4  420.0   87.0              ...                samsung browser 6.2   32.0
#
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ProductCD_oneHot = OneHotEncoder()
ProductCD_oneHot.fit(x_train['ProductCD'].values)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-cd952436a8d9> in <module>
#       1 ProductCD_oneHot = OneHotEncoder()
# ----> 2 ProductCD_oneHot.fit(x_train['ProductCD'].values)
#
# ~\Anaconda\envs\PythonData2\lib\site-packages\sklearn\preprocessing\_encoders.py in fit(self, X, y)
#     425             return self
#     426         else:
# --> 427             self._fit(X, handle_unknown=self.handle_unknown)
#     428             return self
#     429
#
# ~\Anaconda\envs\PythonData2\lib\site-packages\sklearn\preprocessing\_encoders.py in _fit(self, X, handle_unknown)
#      59
#      60     def _fit(self, X, handle_unknown='error'):
# ---> 61         X = self._check_X(X)
#      62
#      63         n_samples, n_features = X.shape
#
# ~\Anaconda\envs\PythonData2\lib\site-packages\sklearn\preprocessing\_encoders.py in _check_X(self, X)
#      45
# ...

# %%
y_train = train_df.iloc[0:,1]
y_train.head()

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier

# %%
classifier.fit(x_train, y_train)
